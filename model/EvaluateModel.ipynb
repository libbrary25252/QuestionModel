# %%
import testuate
from testuate.visualization import radar_plot

# %%
#Import the data
data = [
   {'test_f1': 0.7625, 'test_roc_auc': 0.860402741708885, 'test_accuracy': 0.7283950617283951, 'test_balanced_accuracy': 0.7782251082251082, 'test_runtime': 0.1996},
   {'test_f1': 0.7878787878787878, 'test_roc_auc': 0.8840574311379794, 'test_accuracy': 0.7530864197530864, 'test_balanced_accuracy': 0.8126695526695527, 'test_runtime': 0.2352},
   ]

# %%
model_names = ["BERT", "DistilBERT"]

plot = radar_plot(data=data, model_names=model_names)

plot.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28212\3390721166.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plot.show()

# %%
data = [
   {'f1 score': 0.7625, 'roc auc': 0.860402741708885, 'test_accuracy': 0.7283950617283951, 'test_balanced_accuracy': 0.7782251082251082, 'test_runtime': 0.1996},
   {'test_f1': 0.7878787878787878, 'test_roc_auc': 0.8840574311379794, 'test_accuracy': 0.7530864197530864, 'test_balanced_accuracy': 0.8126695526695527, 'test_runtime': 0.2352},
   ]
